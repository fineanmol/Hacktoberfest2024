# %%
#MLB1-MINOR-APRIL by Shwetank Verma
#email:shwetankverma23@gmail.com

# %%
import os

# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
# %matplotlib inline

# %%
os.chdir('C:/Users/SHWETANK VERMA/Downloads')

# %%
perfo=pd.read_csv('StudentsPerformance.csv')

# %%
perfo.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
perfo.shape
# Out:
# (1000, 8)

# %%
perfo.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
perfo.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
perfo['gender'].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
sns.set_style('whitegrid')

# %%
sns.countplot(x='gender',data=perfo)

# %%
perfo['parental level of education'].value_counts()
# Out:
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental level of education, dtype: int64

# %%
sns.set_style('whitegrid')

# %%
sns.countplot(x='parental level of education',data=perfo)

# %%
perfo['race/ethnicity'].value_counts()
# Out:
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: race/ethnicity, dtype: int64

# %%
sns.set_style('whitegrid')

# %%
sns.countplot(x='race/ethnicity',data=perfo)

# %%
perfo['lunch'].value_counts()
# Out:
# standard        645
# free/reduced    355
# Name: lunch, dtype: int64

# %%
sns.countplot(x='lunch',data=perfo)

# %%
perfo['test preparation course'].value_counts()
# Out:
# none         642
# completed    358
# Name: test preparation course, dtype: int64

# %%
sns.countplot(x='test preparation course',data=perfo)

# %%
sns.set_style('whitegrid')

# %%
sns.countplot(x='gender',hue='race/ethnicity',data=perfo)

# %%
perfo.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
perfo['total score']=perfo['math score']+perfo['reading score']+perfo['writing score']

# %%
perfo['average']=perfo['total score']/3

# %%
sns.distplot(perfo['math score'])

# %%
sns.distplot(perfo['reading score'])

# %%
sns.distplot(perfo['writing score'])

# %%
sns.distplot(perfo['average'])

# %%
sns.pairplot(perfo)

# %%
sns.barplot(perfo['race/ethnicity'],perfo['average'])

# %%
sns.barplot(perfo['parental level of education'],perfo['average'])

# %%
sns.barplot(perfo['test preparation course'],perfo['average'])

# %%
perfo['math result']=np.where(perfo['math score']<40 ,'Fail', 'Pass')

# %%
perfo['reading result']=np.where(perfo['reading score']<40 ,'Fail', 'Pass')

# %%
perfo['writing result']=np.where(perfo['writing score']<40 ,'Fail', 'Pass')

# %%
perfo['overall result']=np.where(perfo['total score']<60 ,'Fail', 'Pass')

# %%
perfo.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    total score    average math result reading result writing result  \
# 0          218  72.666667        Pass           Pass           Pass
# ...

# %%
perfo['overall result'].value_counts()
# Out:
# Pass    998
# Fail      2
# Name: overall result, dtype: int64

# %%
perfo['math result'].value_counts()
# Out:
# Pass    960
# Fail     40
# Name: math result, dtype: int64

# %%
perfo['reading result'].value_counts()
# Out:
# Pass    974
# Fail     26
# Name: reading result, dtype: int64

# %%
perfo['writing result'].value_counts()
# Out:
# Pass    968
# Fail     32
# Name: writing result, dtype: int64

# %%
p=sns.countplot(x='test preparation course',hue='overall result',data=perfo)
